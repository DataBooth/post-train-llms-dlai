# %% [markdown]
# # Setup for pre-cache of HF models used in the course lessons

# %% [markdown]
# Requires the HuggingFace CLI tool to be installed e.g. `brew install huggingface-cli`.
#
# Specify the list of models to be downloaded (if you have already downloaded them they will not be downloaded again.)
#
# Note: The usual cache location is `~/.cache/huggingface`.

# %%
# !ls ~/.cache/huggingface
# Out:
# datasets                            modules
# hub                                 stored_tokens
# models--HuggingFaceTB--SmolLM2-135M token
# models--Qwen--Qwen3-0.6B-Base       xet
# models--banghua--Qwen3-0.6B-SFT

# %%
lesson_models = [
    "Qwen/Qwen3-0.6B-Base",
    "banghua/Qwen3-0.6B-SFT",
    "HuggingFaceTB/SmolLM2-135Mbanghua/Qwen2.5-0.5B-DPO",
    "HuggingFaceTB/SmolLM2-135M-Instruct",
    "banghua/Qwen2.5-0.5B-DPO",
    "Qwen/Qwen2.5-0.5B-Instruct",
    "banghua/Qwen2.5-0.5B-GRPO",
]

# %%
# List of models to be downloaded

hf_models_to_download = [
    "smol-ai/SmolVLM-256M-Instruct",
    "HuggingFaceTB/SmolLM2-135M-Instruct"
]

# %%
import httpx

def hf_models_to_urls_with_status(model_ids, repo_type="model", timeout=5.0):
    """
    For each model ID, build its Hugging Face Hub URL and check if it exists.

    Args:
        model_ids (list of str): List like ['smol-ai/SmolVLM-256M-Instruct']
        repo_type (str): 'model', 'dataset', or 'space'
        timeout (float): HTTP timeout in seconds

    Returns:
        list of dicts with keys: 'id', 'url', 'exists' (bool), 'status_code' (int)
    """
    base_url = "https://huggingface.co"
    if repo_type not in {"model", "dataset", "space"}:
        raise ValueError(f"Invalid repo_type: {repo_type}")

    type_path = {
        "model": "",          # e.g., /facebook/opt-125m
        "dataset": "/datasets",
        "space": "/spaces"
    }[repo_type]

    results = []
    with httpx.Client(timeout=timeout, follow_redirects=True) as client:
        for model_id in model_ids:
            url = f"{base_url}{type_path}/{model_id}"
            try:
                response = client.get(url)
                exists = response.status_code == 200
            except httpx.RequestError as e:
                exists = False
                response = None
                print(f"⚠️ Request to {url} failed: {e}")
            results.append({
                "id": model_id,
                "url": url,
                "exists": exists,
                "status_code": response.status_code if response else None
            })
    return results

# %%
hf_models_to_urls_with_status(hf_models_to_download)
# Out:
# [{'id': 'smol-ai/SmolVLM-256M-Instruct',
#   'url': 'https://huggingface.co/smol-ai/SmolVLM-256M-Instruct',
#   'exists': False,
#   'status_code': 401},
#  {'id': 'HuggingFaceTB/SmolLM2-135M-Instruct',
#   'url': 'https://huggingface.co/HuggingFaceTB/SmolLM2-135M-Instruct',
#   'exists': True,
#   'status_code': 200}]

# %%
def hf_repo_exists(model_id, repo_type="model"):
    """Check if a Hugging Face model/dataset/space exists."""
    base_url = "https://huggingface.co"
    type_path = {
        "model": "",
        "dataset": "/datasets",
        "space": "/spaces"
    }[repo_type]

    url = f"{base_url}{type_path}/{model_id}"
    try:
        resp = httpx.get(url, follow_redirects=True)
        return resp.status_code == 200
    except httpx.RequestError as e:
        print(f"⚠️ Error checking {url}: {e}")
        return False

# %%
# 🔧 Set dry_run = True to skip downloading
dry_run = False  # toggle this to False when you're ready to download

# Download or preview
n_checked = 0
n_found = 0
n_downloaded = 0

for repo in hf_models_to_download:
    print(f"🔎 Checking: {repo}...", end=" ")
    n_checked += 1
    if hf_repo_exists(repo):
        n_found += 1
        print("✅ Found", end=" ")
        if dry_run:
            print("— dry run (skipped download)")
        else:
            print("— downloading")
            # !huggingface-cli download {repo}
            n_downloaded += 1
    else:
        print("❌ Not found — skipped")

print("\n🟩 Summary:")
print(f"  🔍 Checked    : {n_checked}")
print(f"  ✅ Found      : {n_found}")
print(f"  📥 Downloaded : {n_downloaded} {'(dry run)' if dry_run else ''}")
# Out:
# 🔎 Checking: smol-ai/SmolVLM-256M-Instruct... ❌ Not found — skipped
# 🔎 Checking: HuggingFaceTB/SmolLM2-135M-Instruct... ✅ Found — downloading
# Fetching 25 files:   0%|                                 | 0/25 [00:00<?, ?it/s]Downloading 'onnx/model_fp16.onnx' to '/Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/e85e706ce14a3499e1f698c0d638b430df75b5f67131d1516bd0d46b844dfb2e.incomplete'
# Downloading 'onnx/model_quantized.onnx' to '/Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.incomplete' (resume from 137147981/137147981)
# Downloading 'onnx/model_int8.onnx' to '/Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/a7c33f9ef85d06734cc9d1f943f7e2ba57c77e769df727f4d3e217d9f672b0cc.incomplete' (resume from 137147867/137147867)
# Downloading 'onnx/model_q4.onnx' to '/Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/933577110303a2964096d19b6f15d3b4639bef7f99481ac0b61d9f3ad72f392a.incomplete' (resume from 181884823/182068553)
# Downloading 'onnx/model_q4f16.onnx' to '/Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/9358cd4ce037c304621f8c194a525607ae7c5ea73239fcae4c21bd02f2e34ff7.incomplete'
# Downloading 'onnx/model_bnb4.onnx' to '/Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/bc32b446540fe380adb6b29c7e95b0a8402c9e6addb948307daee99735a776bb.incomplete' (resume from 115623709/175434623)
# Downloading 'onnx/model.onnx' to '/Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/1e790f1d6fac94097a6516ed1f07c29049097271d536d538562cd31ffc011a71.incomplete' (resume from 540345794/540345794)
#
# onnx/model_fp16.onnx:   0%|                          | 0.00/270M [00:00<?, ?B/s]
#
# onnx/model_quantized.onnx:   0%|                     | 0.00/137M [00:00<?, ?B/s]
#
#
# onnx/model_q4.onnx:   0%|                            | 0.00/182M [00:00<?, ?B/s]
#
#
#
# onnx/model_int8.onnx:   0%|                          | 0.00/137M [00:00<?, ?B/s]
#
#
#
#
# onnx/model.onnx:   0%|                               | 0.00/540M [00:00<?, ?B/s]
#
#
#
#
#
# onnx/model_bnb4.onnx:   0%|                          | 0.00/175M [00:00<?, ?B/s]
#
#
#
#
#
#
# onnx/model_q4f16.onnx:   0%|                         | 0.00/118M [00:00<?, ?B/s]
#
#
#
#
#
# onnx/model_bnb4.onnx:   1%|▏                 | 2.19M/175M [00:02<03:41, 782kB/s]
#
#
#
# onnx/model_int8.onnx:   2%|▍                 | 2.98M/137M [00:03<02:15, 992kB/s]
#
# onnx/model_quantized.onnx:   2%|▎            | 2.93M/137M [00:03<02:22, 943kB/s]
#
#
#
#
# onnx/model.onnx:   0%|                       | 2.04M/540M [00:03<13:47, 651kB/s]
#
#
# onnx/model_q4.onnx:   1%|▏                   | 2.04M/182M [00:05<08:25, 356kB/s]
#
#
# onnx/model_q4.onnx:  12%|██▎                | 22.2M/182M [00:06<00:31, 5.04MB/s]Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 10.0 seconds)
#
#
#
#
# onnx/model_int8.onnx:   2%|▍                 | 2.98M/137M [00:19<02:15, 992kB/s]
#
#
#
#
# onnx/model.onnx:   2%|▍                      | 8.86M/540M [00:19<13:36, 651kB/s]
#
# onnx/model_quantized.onnx:   2%|▎            | 2.93M/137M [00:19<02:22, 943kB/s]
#
#
# onnx/model_q4.onnx:  15%|██▊                | 27.3M/182M [00:19<00:30, 5.04MB/s]
#
#
#
#
#
# onnx/model_bnb4.onnx:   1%|▏                 | 2.19M/175M [00:19<03:41, 782kB/s]Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 20.0 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 30.1 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 40.1 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 50.1 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 60.2 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 70.2 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 80.2 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 90.2 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 100.3 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 110.3 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 120.4 seconds)
#
# onnx/model_fp16.onnx:   2%|▎              | 6.55M/270M [02:08<1:26:29, 50.8kB/s]Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 130.4 seconds)
#
# onnx/model_fp16.onnx:   2%|▎              | 6.55M/270M [02:19<1:26:29, 50.8kB/s]
#
#
#
#
# onnx/model.onnx:   5%|█                      | 25.0M/540M [02:19<48:58, 175kB/s]Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 140.4 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 150.5 seconds)
#
#
#
#
#
# onnx/model.onnx:   5%|█                      | 25.0M/540M [02:39<48:58, 175kB/s]Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 160.5 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 170.6 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 180.6 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 190.6 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 200.7 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 210.7 seconds)
#
#
#
#
#
#
#
# onnx/model_q4f16.onnx:   9%|█▍              | 10.7M/118M [03:35<35:53, 49.7kB/s]Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 220.7 seconds)
#
#
#
#
#
#
#
# onnx/model_q4f16.onnx:   9%|█▍              | 10.7M/118M [03:49<35:53, 49.7kB/s]Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 230.7 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 240.8 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 250.8 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 260.8 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 270.9 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 280.9 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 291.0 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 301.0 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 311.0 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 321.0 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 331.1 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 341.1 seconds)
#
#
#
#
#
#
# onnx/model_bnb4.onnx:  28%|█████             | 48.7M/175M [05:46<15:11, 139kB/s]Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 351.1 seconds)
#
#
#
#
#
#
# onnx/model_bnb4.onnx:  28%|█████             | 48.7M/175M [05:59<15:11, 139kB/s]Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 361.1 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 371.2 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 381.2 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 391.2 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 401.3 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 411.3 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 421.3 seconds)
#
#
#
#
#
# onnx/model.onnx:  13%|███                    | 71.5M/540M [07:02<46:40, 167kB/s]
#
#
# onnx/model_q4.onnx:  41%|████████            | 73.9M/182M [07:09<11:30, 157kB/s]Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 431.3 seconds)
#
#
#
#
#
# onnx/model.onnx:  13%|███                    | 71.5M/540M [07:19<46:40, 167kB/s]
#
#
# onnx/model_q4.onnx:  41%|████████            | 73.9M/182M [07:19<11:30, 157kB/s]Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 441.4 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 451.4 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 461.4 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 471.4 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 481.5 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 491.5 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 501.5 seconds)
#
#
#
#
#
#
# onnx/model_bnb4.onnx:  66%|████████████▍      | 115M/175M [08:23<04:00, 251kB/s]Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 511.6 seconds)
#
#
#
#
#
#
# onnx/model_bnb4.onnx:  66%|████████████▍      | 115M/175M [08:39<04:00, 251kB/s]Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 521.6 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 531.6 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 541.7 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 551.7 seconds)
#
# onnx/model_fp16.onnx:  13%|█▉             | 35.4M/270M [09:12<1:00:08, 65.1kB/s]Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 561.7 seconds)
#
#
#
#
#
# onnx/model.onnx:  26%|██████▏                 | 139M/540M [09:22<24:20, 275kB/s]
#
#
#
#
# onnx/model.onnx:  38%|█████████▏              | 206M/540M [09:22<10:56, 510kB/s]
#
#
#
#
# onnx/model.onnx:  50%|████████████            | 273M/540M [09:23<05:17, 844kB/s]
#
#
#
#
# onnx/model.onnx:  63%|██████████████▍        | 340M/540M [09:25<02:33, 1.31MB/s]
#
#
#
#
# onnx/model.onnx:  75%|█████████████████▎     | 407M/540M [09:25<01:07, 1.97MB/s]
#
#
#
#
# onnx/model.onnx:  88%|████████████████████▏  | 473M/540M [09:27<00:23, 2.86MB/s]
#
#
#
#
# onnx/model.onnx: 100%|████████████████████████| 540M/540M [09:27<00:00, 951kB/s]
# Download complete. Moving file to /Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/1e790f1d6fac94097a6516ed1f07c29049097271d536d538562cd31ffc011a71
# Fetching 25 files:  36%|█████████                | 9/25 [09:28<16:50, 63.16s/it]Downloading 'runs/Oct31_10-14-22_ip-26-0-174-36/events.out.tfevents.1730370128.ip-26-0-174-36.3239327.0' to '/Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/774faae98f36baa1ee525b594023c5fc25b4ad9249e04ccdf4cba9ee4f4585fd.incomplete'
#
#
#
#
#
# runs/Oct31_10-14-22_ip-26-0-174-36/event(…):   0%|  | 0.00/78.2k [00:00<?, ?B/s]
# onnx/model_fp16.onnx:  13%|█▉             | 35.4M/270M [09:29<1:00:08, 65.1kB/s]
#
#
#
#
# runs/Oct31_10-14-22_ip-26-0-174-36/event(…): 100%|█| 78.2k/78.2k [00:02<00:00, 2
# Download complete. Moving file to /Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/774faae98f36baa1ee525b594023c5fc25b4ad9249e04ccdf4cba9ee4f4585fd
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 571.7 seconds)
# Downloading 'runs/Oct31_10-14-22_ip-26-0-174-36/events.out.tfevents.1730376056.ip-26-0-174-36.3239327.1' to '/Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/043a35029ecb401ef0df75148304075329cd444faf2097b0316e9200018fea5c.incomplete'
#
#
#
#
#
# runs/Oct31_10-14-22_ip-26-0-174-36/event(…):   0%|    | 0.00/828 [00:00<?, ?B/s]
#
#
#
#
# runs/Oct31_10-14-22_ip-26-0-174-36/event(…): 100%|█| 828/828 [00:02<00:00, 413B/
# Download complete. Moving file to /Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/043a35029ecb401ef0df75148304075329cd444faf2097b0316e9200018fea5c
# Downloading 'train_results.json' to '/Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/246b9556e2d21f927f43ff1a0ff9447c5906b46f.incomplete'
#
#
#
#
#
# train_results.json: 100%|██████████████████████| 232/232 [00:00<00:00, 1.67MB/s]
# Download complete. Moving file to /Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/246b9556e2d21f927f43ff1a0ff9447c5906b46f
# Downloading 'trainer_state.json' to '/Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/6870fd88eb2bd4aa2a3c7d3ecb9214bfdddf64f1.incomplete'
#
#
#
#
#
# trainer_state.json: 0.00B [00:00, ?B/s]
#
#
#
#
# trainer_state.json: 57.2kB [00:00, 330kB/s]
# Download complete. Moving file to /Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/6870fd88eb2bd4aa2a3c7d3ecb9214bfdddf64f1
# Downloading 'training_args.bin' to '/Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/90f508e5769b31070c2c8f82e7ecdce816d610763df89479b5258bc66ee8b357.incomplete'
#
#
#
#
#
# training_args.bin:   0%|                            | 0.00/6.52k [00:00<?, ?B/s]
#
#
# onnx/model_q4.onnx:  77%|████████████████▏    | 140M/182M [09:36<02:44, 254kB/s]
#
#
#
#
# training_args.bin: 100%|███████████████████| 6.52k/6.52k [00:01<00:00, 3.34kB/s]
# Download complete. Moving file to /Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/90f508e5769b31070c2c8f82e7ecdce816d610763df89479b5258bc66ee8b357
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 581.7 seconds)
#
#
#
# onnx/model_q4.onnx:  77%|████████████████▏    | 140M/182M [09:49<02:44, 254kB/s]Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 591.7 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 601.7 seconds)
#
#
#
# onnx/model_q4.onnx: 100%|█████████████████████| 182M/182M [10:11<00:00, 298kB/s]
# Download complete. Moving file to /Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/933577110303a2964096d19b6f15d3b4639bef7f99481ac0b61d9f3ad72f392a
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 611.8 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 621.8 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 631.8 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 641.8 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 651.9 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 661.9 seconds)
#
# onnx/model_fp16.onnx:  28%|█████             | 75.4M/270M [11:04<24:10, 134kB/s]
#
#
#
#
#
#
# onnx/model_q4f16.onnx:  43%|██████▉         | 50.7M/118M [11:04<14:07, 79.1kB/s]Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 671.9 seconds)
#
# onnx/model_fp16.onnx:  28%|█████             | 75.4M/270M [11:19<24:10, 134kB/s]
#
#
#
#
#
#
# onnx/model_q4f16.onnx:  43%|██████▉         | 50.7M/118M [11:19<14:07, 79.1kB/s]Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 681.9 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 691.9 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 701.9 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 712.0 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 722.0 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 732.0 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 742.0 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 752.1 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 762.1 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 772.1 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 782.1 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 792.2 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 802.2 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 812.2 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 822.2 seconds)
#
#
#
#
#
#
# onnx/model_bnb4.onnx: 100%|███████████████████| 175M/175M [13:47<00:00, 212kB/s]
# Download complete. Moving file to /Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/bc32b446540fe380adb6b29c7e95b0a8402c9e6addb948307daee99735a776bb
# Fetching 25 files:  40%|█████████▌              | 10/25 [13:47<22:30, 90.03s/it]Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 832.3 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 842.3 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 852.3 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 862.3 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 872.4 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 882.4 seconds)
#
# onnx/model_fp16.onnx:  50%|█████████▌         | 136M/270M [14:42<11:39, 192kB/s]Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 892.4 seconds)
#
# onnx/model_fp16.onnx:  50%|█████████▌         | 136M/270M [14:59<11:39, 192kB/s]Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 902.4 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 912.5 seconds)
# Still waiting to acquire lock on /Users/mjboothaus/.cache/huggingface/hub/.locks/models--HuggingFaceTB--SmolLM2-135M-Instruct/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39.lock (elapsed: 922.5 seconds)
#
#
#
#
# onnx/model_int8.onnx:  51%|████████▋        | 70.1M/137M [15:26<14:57, 74.8kB/s]
#
# onnx/model_quantized.onnx:  51%|██████▏     | 70.0M/137M [15:28<14:59, 74.6kB/s]
# onnx/model_fp16.onnx:  75%|██████████████▎    | 203M/270M [15:28<03:25, 327kB/s]
#
#
#
#
#
#
# onnx/model_q4f16.onnx: 100%|██████████████████| 118M/118M [15:28<00:00, 127kB/s]
# Download complete. Moving file to /Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/9358cd4ce037c304621f8c194a525607ae7c5ea73239fcae4c21bd02f2e34ff7
#
#
#
#
# onnx/model_int8.onnx: 100%|███████████████████| 137M/137M [15:30<00:00, 147kB/s]
# Download complete. Moving file to /Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/a7c33f9ef85d06734cc9d1f943f7e2ba57c77e769df727f4d3e217d9f672b0cc
#
#
# onnx/model_quantized.onnx: 100%|██████████████| 137M/137M [15:30<00:00, 147kB/s]
# Download complete. Moving file to /Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/ecc1a19eece6494e2963cf74f78ace35916e8d0b803168ddd41db00979f18e39
#
# onnx/model_fp16.onnx: 100%|███████████████████| 270M/270M [15:30<00:00, 290kB/s]
# Download complete. Moving file to /Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/blobs/e85e706ce14a3499e1f698c0d638b430df75b5f67131d1516bd0d46b844dfb2e
# Fetching 25 files: 100%|████████████████████████| 25/25 [15:31<00:00, 37.24s/it]
# /Users/mjboothaus/.cache/huggingface/hub/models--HuggingFaceTB--SmolLM2-135M-Instruct/snapshots/a91318be21aeaf0879874faa161dcb40c68847e9
#
# 🟩 Summary:
#   🔍 Checked    : 2
#   ✅ Found      : 1
#   📥 Downloaded : 1
